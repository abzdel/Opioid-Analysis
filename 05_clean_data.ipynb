# %%
import pandas as pd
from datetime import datetime
import numpy as np

# %%
orig_cols_to_keep = ["REPORTER_DEA_NO", "REPORTER_STATE", "REPORTER_ZIP", "REPORTER_COUNTY", "DRUG_CODE", "TRANSACTION_CODE", "DRUG_NAME", "QUANTITY", "TRANSACTION_DATE", "CALC_BASE_WT_IN_GM", "DOSAGE_UNIT",
                "TRANSACTION_ID", "Product_Name", "Ingredient_Name", "Measure", "dos_str"]
# keeping more columns than is probably necessary
# just want to make sure we have everything we need, as well as have the opportunity to catch any further filtering we miss at first
pd.set_option('display.max_columns', None)

# %%
def find_year(TRANSACTION_DATE):
    """
    Args:
        TRANSACTION_DATE (str): date in format MMDDYYYY

    Returns:
        int: year
    """
    TRANSACTION_DATE = str(TRANSACTION_DATE)
    
    return int(TRANSACTION_DATE[-4:])

# quick test 
find_year(12202019)
# Out:
# 2019

# %%
cols_to_keep = ["REPORTER_DEA_NO", "REPORTER_STATE", "REPORTER_ZIP", "REPORTER_COUNTY", "DRUG_CODE", "TRANSACTION_CODE", "DRUG_NAME", "QUANTITY", "TRANSACTION_DATE", "Product_Name"]

it = pd.read_csv("00_source_data/arcos_all_washpost.tsv", chunksize=500_000, sep='\t', usecols = cols_to_keep) # may have to change chunksize depending on your computer's memory


df = pd.DataFrame()

for chunk in it:
    # extract year out of date column
    chunk["year"] = chunk["TRANSACTION_DATE"].apply(lambda x: find_year(x))

    # ensure we're working in the correct date range
    filtered_chunk = chunk[chunk["year"] > 2002]
    filtered_chunk = filtered_chunk[filtered_chunk["year"] < 2016]

    df = df.append(filtered_chunk)
    break
df
# Out:
#        REPORTER_DEA_NO REPORTER_STATE  REPORTER_ZIP REPORTER_COUNTY  \
# 0            PA0006836             MA          2301        PLYMOUTH
# 1            PA0021179             AZ         85006        MARICOPA
# 2            PA0021179             AZ         85006        MARICOPA
# 3            PA0021179             AZ         85006        MARICOPA
# 4            PA0021179             AZ         85006        MARICOPA
# ...                ...            ...           ...             ...
# 499995       RC0238104             TN         37931            KNOX
# 499996       RC0238104             TN         37931            KNOX
# 499997       RC0238104             TN         37931            KNOX
# 499998       RC0238104             TN         37931            KNOX
# 499999       RC0238104             TN         37931            KNOX
#
#        TRANSACTION_CODE  DRUG_CODE    DRUG_NAME  QUANTITY  TRANSACTION_DATE  \
# 0                     S       9193  HYDROCODONE       1.0          12262012
# 1                     S       9193  HYDROCODONE       4.0           3112009
# 2                     S       9193  HYDROCODONE      40.0          11252008
# 3                     S       9193  HYDROCODONE      20.0           6122009
# 4                     S       9193  HYDROCODONE      10.0          10022009
# ...                 ...        ...          ...       ...               ...
# 499995                S       9193  HYDROCODONE       1.0          11112010
# 499996                S       9193  HYDROCODONE       1.0          12032010
# 499997                S       9193  HYDROCODONE       1.0          12082010
# 499998                S       9143    OXYCODONE       2.0          12092010
# 499999                S       9143    OXYCODONE       1.0           7102007
#
#                                 Product_Name  year
# 0       HYDROCODONE BIT/ACETA 10MG/500MG USP  2012
# 1       HYDROCODONE BITARTRATE & ACETA  5MG/  2009
# 2       HYDROCODONE BITARTRATE & ACETA  5MG/  2008
# 3       HYDROCODONEBITARTRATE & ACETA  7.5MG  2009
# 4       HYDROCODONE BITARTRATE & ACETA  5MG/  2009
# ...                                      ...   ...
# 499995   HYDROCODONE BIT & ACETA 7.5MG/500MG  2010
# 499996  HYDROCODONE BIT/ACETA 7.5MG/325MG US  2010
# 499997  HYDROCODONE BITARTRATE/APAP 10MG/500  2010
# 499998   OXYCODONE HYDROCHLORIDE 30MG TABLET  2010
# 499999  PERCOCET TABLETS OXYCODONE HCL 7.5MG  2007
#
# [500000 rows x 11 columns]
